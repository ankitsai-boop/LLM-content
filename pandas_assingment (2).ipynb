# %% [markdown]
# ## <font color="maroon"><h4 align="center"> Comprehensive Pandas Exercise: Basics & Missing Data </font>

# %% [markdown]
# **Scenario:**
# You are a Data Analyst working for **Gadget Galaxy**, a popular electronics retail chain. Your manager has provided you with a recent extract of smartphone sales data. However, the data is messy, contains missing values, and needs some adjustments before it can be used for final reporting.
#
# Your task is to analyze the data, clean it up by handling missing values, apply new promotional discounts, and prepare the final dataset.
#
# *Note: Run the cell below to generate the `smartphone_sales.csv` dataset required for this assignment.*

# %%
import pandas as pd
import numpy as np

# Run this cell to generate the dataset
data = {
    'Date': ['2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04', '2023-10-05', '2023-10-06', '2023-10-07', '2023-10-08'],
    'Brand': ['Apple', 'Samsung', 'Apple', 'Xiaomi', 'Samsung', 'Apple', np.nan, 'Xiaomi'],
    'Model': ['iPhone 14', 'Galaxy S23', 'iPhone 13', 'Redmi Note 12', 'Galaxy A54', 'iPhone 14 Pro', 'Unknown', 'Poco X5'],
    'Price': [799, 899, 599, 199, 450, 999, 300, 250],
    'Discount': ['5%', '10%', '0%', '10%', '5%', '0%', '15%', '5%'],
    'Units_Sold': [120, np.nan, 85, 300, np.nan, 90, 45, 150],
    'Customer_Rating': ['Excellent', 'Good', np.nan, 'Average', np.nan, 'Excellent', 'Poor', 'Good']
}
df_setup = pd.DataFrame(data)
df_setup.to_csv('smartphone_sales.csv', index=False)
print("Dataset 'smartphone_sales.csv' has been created successfully!")

# %% [markdown]
# ### <font color="purple">**Question 1: DataFrame Basics**</font>
# - Read the csv file 'smartphone_sales.csv' and store it in the variable 'df'.
# - Print the number of rows and columns in the dataframe.
# - Display the Top 5 rows.

# %%
# Read the csv file


# Show the number of rows and columns


# Show Top 5 rows

# %% [markdown]
# ### <font color="purple">**Question 2: Finding Unique Values**</font>
# - Show the unique categories present in the **'Brand'** and **'Customer_Rating'** columns.

# %%
# Unique values in 'Brand' column


# Unique values in 'Customer_Rating' column

# %% [markdown]
# ### <font color="purple">**Question 3: Filtering Data**</font>
# - Filter the data to show only phones where the **Brand** is **'Apple'** AND the **Price** is greater than **600**.
# - Print the count of how many rows match this condition.

# %%
# Filter the data

# %% [markdown]
# ### <font color="purple">**Question 4: Creating New Columns**</font>
# - Add a new column called **'Price_Category'** based on the phone's price.
# - If the price is less than 500, categorize it as **"Budget"**, otherwise categorize it as **"Premium"**.
# - Display the Top 5 rows of the updated dataframe.

# %%
# Add the 'Price_Category' column


# Show the updated dataframe

# %% [markdown]
# ### <font color="purple">**Question 5: Handling Missing Data (Mean)**</font>
# - Some values in the **'Units_Sold'** column are missing.
# - Fill these missing (NaN) values with the **mean (average)** value of the 'Units_Sold' column.
# - Store the changes directly into the 'df' variable (or reassign it).

# %%
# Fill null values in 'Units_Sold' with the column's mean


# Display the dataframe to verify changes

# %% [markdown]
# ### <font color="purple">**Question 6: Handling Missing Data (Forward Fill)**</font>
# - There are missing values in the **'Customer_Rating'** column.
# - Fill these null values using the **forward fill** method (`ffill`), which uses the previous row's non-null value.
# - Note: Store the result back into 'df'.

# %%
# Fill null values in 'Customer_Rating' using 'ffill'


# Display the dataframe to verify changes

# %% [markdown]
# ### <font color="purple">**Question 7: Handling Missing Data (Replace Method)**</font>
# - The marketing team decided to standardize discounts.
# - Replace all **'5%'** and **'10%'** values in the **'Discount'** column with a standard **'12%'**.
# - Display the updated dataframe.

# %%
# Replace '5%' and '10%' with '12%'

# %% [markdown]
# ### <font color="purple">**Question 8: Handling Missing Data (Dropna with Threshold)**</font>
# - Drop any row that does not contain at least **7 non-null** values (use the `thresh` parameter).
# - Store this fully cleaned dataframe in a new variable called **'final_df'**.

# %%
# Drop rows with less than 7 non-null values

# %% [markdown]
# ### <font color="purple">**Question 9: Saving the Data**</font>
# - Save the `final_df` dataframe to a new CSV file named **'final_smartphone_sales.csv'**.
# - Ensure that the index is not saved to the file (set `index=False`).

# %%
# Save the dataframe to csv
